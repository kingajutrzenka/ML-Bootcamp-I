# %% [markdown]
# <a href="https://colab.research.google.com/github/kingajutrzenka/ML-Bootcamp-I/blob/main/ekstrakcja_cech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Ekstrakcja Cech**

# %% [markdown]
# # Import bibliotek

# %%
import numpy as np
import pandas as pd
import sklearn
sklearn.__version__
# Out:
# '1.6.1'

# %% [markdown]
# # Załadowanie danych

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#                Open    High       Low   Close    Volume
# Date
# 2025-08-08  223.140  223.80  221.8836  222.69  32970477
# 2025-08-07  221.000  226.22  220.8200  223.13  40603513
# 2025-08-06  214.695  222.65  213.7409  222.31  54823045
# 2025-08-05  213.050  216.30  212.8700  213.75  51505121
# 2025-08-04  217.400  217.44  211.4200  211.65  77890146

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2025-08-08 to 2025-08-04
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# # Nowe zmienne

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                Open    High       Low   Close    Volume  day  month  year
# Date
# 2025-08-08  223.140  223.80  221.8836  222.69  32970477    8      8  2025
# 2025-08-07  221.000  226.22  220.8200  223.13  40603513    7      8  2025
# 2025-08-06  214.695  222.65  213.7409  222.31  54823045    6      8  2025
# 2025-08-05  213.050  216.30  212.8700  213.75  51505121    5      8  2025
# 2025-08-04  217.400  217.44  211.4200  211.65  77890146    4      8  2025

# %% [markdown]
# # Dyskretyzacja zmiennej ciągłej

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=3) # samo dzieli
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height', dtype = 'int')
# Out:
#    height  height_medium  height_high
# 0   175.0              0            0
# 1   178.5              1            0
# 2   185.0              0            1
# 3   191.0              0            1
# 4   184.5              0            1
# 5   183.0              0            1
# 6   168.0              0            0

# %% [markdown]
# # Ekstrakcja cech

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len) # liczy ile jest języków
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0) # funkcja sprawdza, czy jest polska
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True) #dzielimy na 2 kolumny
# Out:
#         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# tak robimy to na stałe
